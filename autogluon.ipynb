# %%
# !pip install autogluon
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: C:\Users\nicho\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

mydata = pd.read_csv(r'C:\Users\nicho\OneDrive\Documents\CNIT 484\archive\Loan.csv')

# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# Load the trained predictor
predictor = TabularPredictor(label="LoanApproved", path=r"c:\Users\nicho\AppData\Local\Programs\Microsoft VS Code\LoanApprovalModel/").fit(mydata)

# Evaluate on the same data or on a test dataset
evaluation_results = predictor.evaluate(mydata)
leaderboard = predictor.leaderboard(silent=True)

output_path = "C:/Users/Nicho/Documents/model_evaluation_results.txt"

# Save evaluation results to a text file
with open(output_path, "w") as f:
    f.write("AutoGluon Model Evaluation Results\n")
    f.write("="*50 + "\n")
    for metric, value in evaluation_results.items():
        f.write(f"{metric}: {value}\n")

output_path = "C:/Users/Nicho/Documents/autogluon_leaderboard.csv"

# Save leaderboard (ranking of all models) to CSV
leaderboard.to_csv(output_path, index=False)

print("Evaluation results saved to model_evaluation_results.txt")
print("Leaderboard saved to autogluon_leaderboard.csv")
# Out:
# ...
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          16
# Memory Avail:       2.62 GB / 15.68 GB (16.7%)
# Disk Space Avail:   261.49 GB / 932.85 GB (28.0%)
# ...
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# ...

# %%
with open("C:/Users/Nicho/Documents/model_evaluation_results.txt", "r") as f:
    print(f.read())
# Out:
# AutoGluon Model Evaluation Results
# ...
# accuracy: 0.99975
# balanced_accuracy: 0.999692240445571
# mcc: 0.9993127886395877
# roc_auc: 0.9999966873580787
# f1: 0.9994770421504027
# precision: 0.9993725162099979
# recall: 0.999581589958159

# %%
import pandas as pd

leaderboard = pd.read_csv("C:/Users/Nicho/Documents/autogluon_leaderboard.csv")
print(leaderboard)
# Out:
#                   model  score_val eval_metric  pred_time_val   fit_time  \
# 0   WeightedEnsemble_L2     1.0000    accuracy       0.029554  11.352723
# 1       NeuralNetFastAI     1.0000    accuracy       0.029554  11.279084
# 2              CatBoost     0.9995    accuracy       0.006004  13.794882
# 3              LightGBM     0.9995    accuracy       0.010514   1.145463
# 4            LightGBMXT     0.9990    accuracy       0.010517   0.913697
# 5               XGBoost     0.9965    accuracy       0.016031   1.056554
# 6         LightGBMLarge     0.9960    accuracy       0.011518   1.270755
# 7        ExtraTreesEntr     0.9905    accuracy       0.056234   0.892197
# 8        ExtraTreesGini     0.9900    accuracy       0.054036   0.911234
# 9      RandomForestGini     0.9880    accuracy       0.055759   2.132275
# 10     RandomForestEntr     0.9880    accuracy       0.079623   2.490914
# 11       KNeighborsUnif     0.7100    accuracy       0.052595   0.021558
# ...

# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# Load the trained predictor
predictor = TabularPredictor(label="PreviousLoanDefaults", path=r"c:\Users\nicho\AppData\Local\Programs\Microsoft VS Code\PreviousLoanDefaultsModel").fit(mydata)


# Evaluate on the same data or on a test dataset
evaluation_results = predictor.evaluate(mydata)
leaderboard = predictor.leaderboard(silent=True)

output_path = "C:/Users/Nicho/Documents/PreviousLoanDefaults_model_evaluation_results.txt"


# Save evaluation results to a text file
with open(output_path, "w") as f:
    f.write("AutoGluon Model Evaluation Results\n")
    f.write("="*50 + "\n")
    for metric, value in evaluation_results.items():
        f.write(f"{metric}: {value}\n")

output_path = "C:/Users/Nicho/Documents/PreviousLoanDefaults_autogluon_leaderboard.csv"

# Save leaderboard (ranking of all models) to CSV
leaderboard.to_csv(output_path, index=False)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          16
# Memory Avail:       2.14 GB / 15.68 GB (13.6%)
# Disk Space Avail:   261.49 GB / 932.85 GB (28.0%)
# ...
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# ...

# %%
with open("C:/Users/Nicho/Documents/PreviousLoanDefaults_model_evaluation_results.txt", "r") as f:
    print(f.read())
# Out:
# AutoGluon Model Evaluation Results
# ...
# accuracy: 1.0
# balanced_accuracy: 1.0
# mcc: 1.0
# roc_auc: 1.0
# f1: 1.0
# precision: 1.0
# recall: 1.0

# %%
leaderboard = pd.read_csv("C:/Users/Nicho/Documents/PreviousLoanDefaults_autogluon_leaderboard.csv")
print(leaderboard)
# Out:
#                   model  score_val eval_metric  pred_time_val   fit_time  \
# 0              CatBoost     1.0000    accuracy       0.006522  31.913756
# 1   WeightedEnsemble_L2     1.0000    accuracy       0.007523  31.986522
# 2       NeuralNetFastAI     0.9995    accuracy       0.025044  17.476485
# 3              LightGBM     0.9975    accuracy       0.021030   2.838941
# 4            LightGBMXT     0.9955    accuracy       0.020027   2.281592
# 5               XGBoost     0.9945    accuracy       0.014508   2.246584
# 6         LightGBMLarge     0.9880    accuracy       0.016033   3.077214
# 7      RandomForestGini     0.9320    accuracy       0.055218   3.124211
# 8      RandomForestEntr     0.9245    accuracy       0.054123   3.585657
# 9        ExtraTreesEntr     0.9000    accuracy       0.065610   1.051869
# 10       ExtraTreesGini     0.9000    accuracy       0.076119   1.016083
# 11       KNeighborsUnif     0.8905    accuracy       0.047073   0.017523
# ...

# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# Load the trained predictor
# change the path according to where the file is located 
predictor = TabularPredictor(label="TotalAssets", path=r"c:\Users\nicho\AppData\Local\Programs\Microsoft VS Code\TotalAssets/").fit(mydata)

# Evaluate on the same data or on a test dataset
evaluation_results = predictor.evaluate(mydata)
leaderboard = predictor.leaderboard(silent=True)

output_path = "C:/Users/Nicho/Documents/TotalAssets_model_evaluation_results.txt"

# Save evaluation results to a text file
with open(output_path, "w") as f:
    f.write("AutoGluon TotalAssets Model Evaluation Results\n")
    f.write("="*50 + "\n")
    for metric, value in evaluation_results.items():
        f.write(f"{metric}: {value}\n")

output_path = "C:/Users/Nicho/Documents/TotalAssets_autogluon_leaderboard.csv"

# Save leaderboard (ranking of all models) to CSV
leaderboard.to_csv(output_path, index=False)
# Out:
# ...
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          16
# Memory Avail:       2.99 GB / 15.68 GB (19.1%)
# Disk Space Avail:   260.82 GB / 932.85 GB (28.0%)
# ...
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# ...

# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# Load the trained predictor
# change the path according to where the file is located 
predictor = TabularPredictor(label="EducationLevel", path=r"c:\Users\nicho\AppData\Local\Programs\Microsoft VS Code\EducationModel/").fit(mydata)

# Evaluate on the same data or on a test dataset
evaluation_results = predictor.evaluate(mydata)
leaderboard = predictor.leaderboard(silent=True)

output_path = "C:/Users/Nicho/Documents/Education_model_evaluation_results.txt"

# Save evaluation results to a text file
with open(output_path, "w") as f:
    f.write("AutoGluon Education Model Evaluation Results\n")
    f.write("="*50 + "\n")
    for metric, value in evaluation_results.items():
        f.write(f"{metric}: {value}\n")

output_path = "C:/Users/Nicho/Documents/education_autogluon_leaderboard.csv"

# Save leaderboard (ranking of all models) to CSV
leaderboard.to_csv(output_path, index=False)
# Out:
# ...
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.11.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          16
# Memory Avail:       3.00 GB / 15.68 GB (19.1%)
# Disk Space Avail:   260.82 GB / 932.85 GB (28.0%)
# ...
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# ...
